# %% [markdown]
# <a href="https://colab.research.google.com/github/paolax4l/PYTHON.EXCERCISES/blob/main/exercise3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Άσκηση 1
#
# Φτιάξτε ένα σύνολο δεδομένων με πληροφορίες για 3 άρθρα από ένα δημοσιογραφικό site της επιλογής σας.
#
# Οι πληροφορίες για κάθε άρθρο, θα είναι:
# - τίτλος του άρθρου
# - url του άρθρου
# - συντάκτης του άρθρου
# - θεματική κατηγορία άρθρου
# - ημερομηνία δημοσίευσης του άρθρου
#
# Οι πληροφορίες για κάθε άρθρο θα τοποθετηθούν σε ένα λεξικό.
#
# Το σύνολο των δεδομένων της αρθρογραφίας των 3 άρθρων θα είναι μια λίστα, η οποία θα περιέχει τα 3 λεξικά.
#
# **Παράδειγμα λεξικού (dictionary) με πληροφορίες για ένα άρθρο**:
# ```
# articleD_1 = {
#   "title": "Συναγερμός για κρούσμα κροτωνογενούς εγκεφαλίτιδας στην Ελλάδα – Εγκύκλιος ΕΟΔΥ",
#   "url": "https://www.news247.gr/ygeia/sinagermos-gia-krousma-krotonogenous-egkefalitidas-stin-ellada-egkiklios-eodi/",
#   "author": "ΓΙΑΝΝΗΣ ΔΕΒΕΤΖΟΓΛΟΥ",
#   "section": "Υγεία",
#   "date": "27 Μαρτίου 2025 13:40"
# }
# ```
#
# **Hints & Tips:**
# - αρχικά μπορείτε να δημιουργήσετε μια κενή λίστα με όνομα π.χ. "articlesL"
# - στη συνέχεια μπορείτε να δημιουργείτε ένα-ένα τα λεξικά με τις πληροφορίες για τα άρθρα (όπως στο παραπάνω παράδειγμα) και
# - να προσθέτε ένα-ένα τα λεξικά στη λίστα με append()
# - τέλος, καλέστε τη λίστα των άρθρων με το όνομά της για να εμφανιστεί στην οθόνη (μπορείτε να την κάνετε και print για να δείτε τη διαφορά στον τρόπο που εμφανίζεται η λίστα στην οθόνη)

# %%
articelsL = []

# %% [markdown]
# ---

# %%
articleD_1 = {
"title" : "Αλλαγές και ανατροπές φέρνει το νομοσχέδιο του υπουργείου Δικαιοσύνης",
"url" : "https://www.efsyn.gr/politiki/kybernisi/467907_allages-kai-anatropes-fernei-nomoshedio-toy-ypoyrgeioy-dikaiosynis",
"author" : "ΓΙΩΡΓΟΣ ΚΟΝΤΑΡΙΝΗΣ",
"section" : "ΚΥΒΕΡΝΗΣΗ",
"date" : "01.04.25 16:06"

}

# %%
articleD_2 = {
"title" : "Η προδιαγεγραμμένη πτώση μιας επιτυχημένης 55χρονης ηρωίδας",
"url" : "https://www.efsyn.gr/tehnes/theatro/467749_i-prodiagegrammeni-ptosi-mias-epityhimenis-55hronis-iroidas",
"author" : "Γρηγόρης Ιωαννίδης",
"section" : "ΘΕΑΤΡΟ",
"date" : "31.03.25 21:30"
}

# %%
articleD_3 = {
"title" : "Ασλανίδης σε Μπακαΐμη: Μετρήστε τα οστά, δώστε μας τα βίντεο, θέλουμε απαντήσεις",
"url" : "https://www.efsyn.gr/ellada/dikaiosyni/467913_aslanidis-se-mpakaimi-metriste-ta-osta-doste-mas-ta-binteo-theloyme",
"author" : "ΜΙΧΑΛΗΣ ΚΑΡΑΓΙΑΝΝΗΣ",
"section" : "ΔΙΚΑΙΟΣΥΝΗ",
"date" : "01.04.25 16:30"
}

# %%
articelsL.append(articleD_1)
articelsL.append(articleD_2)
articelsL.append(articleD_3)

# %%
print(articelsL)
# Out:
# [{'title': 'Αλλαγές και ανατροπές φέρνει το νομοσχέδιο του υπουργείου Δικαιοσύνης', 'url': 'https://www.efsyn.gr/politiki/kybernisi/467907_allages-kai-anatropes-fernei-nomoshedio-toy-ypoyrgeioy-dikaiosynis', 'author': 'ΓΙΩΡΓΟΣ ΚΟΝΤΑΡΙΝΗΣ', 'section': 'ΚΥΒΕΡΝΗΣΗ', 'date': '01.04.25 16:06'}, {'title': 'Η προδιαγεγραμμένη πτώση μιας επιτυχημένης 55χρονης ηρωίδας', 'url': 'https://www.efsyn.gr/tehnes/theatro/467749_i-prodiagegrammeni-ptosi-mias-epityhimenis-55hronis-iroidas', 'author': 'Γρηγόρης Ιωαννίδης', 'section': 'ΘΕΑΤΡΟ', 'date': '31.03.25 21:30'}, {'title': 'Ασλανίδης σε Μπακαΐμη: Μετρήστε τα οστά, δώστε μας τα βίντεο, θέλουμε απαντήσεις', 'url': 'https://www.efsyn.gr/ellada/dikaiosyni/467913_aslanidis-se-mpakaimi-metriste-ta-osta-doste-mas-ta-binteo-theloyme', 'author': 'ΜΙΧΑΛΗΣ ΚΑΡΑΓΙΑΝΝΗΣ', 'section': 'ΔΙΚΑΙΟΣΥΝΗ', 'date': '01.04.25 16:30'}]

# %% [markdown]
# ### Άσκηση 2
#
# Μετατρέψτε τη λίστα με τα λεξικά που φτιάξατε στην προηγούμενη άσκηση σε pandas dataframe.
#
# **Hints & Tips:**
# - Εισάγετε τη βιβλιοθήκη pandas με την εντολή ```import pandas as pd```
# - Δημιουργήστε ένα dataframe με όνομα ```df```, με την εντολή ```df = pd.DataFrame(articlesL)```
# - Καλέστε το df για να εμφανιστεί στην οθόνη

# %%
import pandas as pd
articlesL = [
    {
"title" : "Αλλαγές και ανατροπές φέρνει το νομοσχέδιο του υπουργείου Δικαιοσύνης",
"url" : "https://www.efsyn.gr/politiki/kybernisi/467907_allages-kai-anatropes-fernei-nomoshedio-toy-ypoyrgeioy-dikaiosynis",
"author" : "ΓΙΩΡΓΟΣ ΚΟΝΤΑΡΙΝΗΣ",
"section" : "ΚΥΒΕΡΝΗΣΗ",
"date" : "01.04.25 16:06"

},
{
"title" : "Η προδιαγεγραμμένη πτώση μιας επιτυχημένης 55χρονης ηρωίδας",
"url" : "https://www.efsyn.gr/tehnes/theatro/467749_i-prodiagegrammeni-ptosi-mias-epityhimenis-55hronis-iroidas",
"author" : "Γρηγόρης Ιωαννίδης",
"section" : "ΘΕΑΤΡΟ",
"date" : "31.03.25 21:30"
} ,
   {"title" : "Ασλανίδης σε Μπακαΐμη: Μετρήστε τα οστά, δώστε μας τα βίντεο, θέλουμε απαντήσεις",
"url" : "https://www.efsyn.gr/ellada/dikaiosyni/467913_aslanidis-se-mpakaimi-metriste-ta-osta-doste-mas-ta-binteo-theloyme",
"author" : "ΜΙΧΑΛΗΣ ΚΑΡΑΓΙΑΝΝΗΣ",
"section" : "ΔΙΚΑΙΟΣΥΝΗ",
"date" : "01.04.25 16:30"}

]
df = pd.DataFrame(articlesL)
print(df)
# Out:
#                                                title  \
# 0  Αλλαγές και ανατροπές φέρνει το νομοσχέδιο του...
# 1  Η προδιαγεγραμμένη πτώση μιας επιτυχημένης 55χ...
# 2  Ασλανίδης σε Μπακαΐμη: Μετρήστε τα οστά, δώστε...
#
#                                                  url               author  \
# 0  https://www.efsyn.gr/politiki/kybernisi/467907...   ΓΙΩΡΓΟΣ ΚΟΝΤΑΡΙΝΗΣ
# 1  https://www.efsyn.gr/tehnes/theatro/467749_i-p...   Γρηγόρης Ιωαννίδης
# 2  https://www.efsyn.gr/ellada/dikaiosyni/467913_...  ΜΙΧΑΛΗΣ ΚΑΡΑΓΙΑΝΝΗΣ
#
#       section            date
# 0   ΚΥΒΕΡΝΗΣΗ  01.04.25 16:06
# 1      ΘΕΑΤΡΟ  31.03.25 21:30
# 2  ΔΙΚΑΙΟΣΥΝΗ  01.04.25 16:30

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 3 (intro)
#
# Στο site "ourworldindata.org" παρέχονται πάρα πολλά δεδομένα και γραφήματα για διάφορα topics για όλες τις χώρες του κόσμου.
#
# Για παράδειγμα, στη σελίδα https://ourworldindata.org/explorers/covid?Metric=Excess+mortality+%28estimates%29&Interval=Cumulative&Relative+to+population=false&country=USA~BRA~JPN~DEU, παρέχονται δεδομένα και γραφήματα σχετικά με την Covid-19.
#
# Αν επισκεφθείτε την παραπάνω σελίδα, επάνω αριστερά, υπάρχει ένας υπερσύνδεσμος με το κείμενο "Download this dataset". Εάν τον πατήσετε θα οδηγηθείτε στη σελίδα με τα datasets για τον covid.
#
# Πιο κάτω, σ' αυτή τη σελίδα, υπάρχει η ενότητα "Download data", με πολλά κουμπάκια download.
#
# Όταν πατήσετε κάποιο download μεταφέρεστε στη σελίδα του raw αρχείου csv με τα δεδομένα.
#
# Μπορούμε να φέρουμε αυτά τα δεδομένα σε ένα dataframe στην Python, με την παρακάτω εντολή:

# %%
import pandas as pd

covid_df = pd.read_csv("https://catalog.ourworldindata.org/garden/covid/latest/cases_deaths/cases_deaths.csv")
covid_df
# Out:
#             country        date  new_cases  total_cases  new_deaths  \
# 0       Afghanistan  2020-01-04        0.0            0         0.0
# 1       Afghanistan  2020-01-05        0.0            0         0.0
# 2       Afghanistan  2020-01-06        0.0            0         0.0
# 3       Afghanistan  2020-01-07        0.0            0         0.0
# 4       Afghanistan  2020-01-08        0.0            0         0.0
# ...             ...         ...        ...          ...         ...
# 471245     Zimbabwe  2025-02-26        0.0       266410         0.0
# 471246     Zimbabwe  2025-02-27        0.0       266410         0.0
# 471247     Zimbabwe  2025-02-28        0.0       266410         0.0
# 471248     Zimbabwe  2025-03-01        0.0       266410         0.0
# 471249     Zimbabwe  2025-03-02        0.0       266410         0.0
#
#         total_deaths  weekly_cases  weekly_deaths  weekly_pct_growth_cases  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 3 (actual part)
#
# Βρείτε από το ourworldindata.org ένα dataset που σας ενδιαφέρει και ανοίξτε το σαν dataframe.

# %%
import pandas as pd
covid_df = pd.read_csv("https://catalog.ourworldindata.org/garden/covid/latest/covax/covax.csv")
covid_df
# Out:
#                  country  year  delivered  only_donated  only_announced  \
# 0              Australia  2022          0             0        60000000
# 1                Austria  2022    1200000       2000000               0
# 2                Belgium  2022    8200000       4400000         2400000
# 3                 Brazil  2022          0       5100000        16900000
# 4                 Canada  2022   14200000      15200000        21600000
# 5                Denmark  2022    7300000             0          700000
# 6    European Union (27)  2022  286300000     109000000       131300000
# 7                Finland  2022    2800000        300000          900000
# 8                 France  2022   61300000      16100000        42600000
# 9                Germany  2022   92100000      33400000        49500000
# 10                Greece  2022    4300000             0               0
# 11             Hong Kong  2022     900000       6600000          500000
# ...
